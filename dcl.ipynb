# %%
# %load_ext sql
# %sql mysql+pymysql://root:root@localhost/first

# %%
# %%sql
#
# GRANT SELECT,INSERT
# ON employee
# TO root@localhost;
#
# #permission to just read,insert
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 0 rows affected.
# []

# %%
# %%sql
#
# REVOKE INSERT
# ON employee
# FROM root@localhost

# %%
# %%sql
# DROP USER 'pushpa'@'localhost';
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 0 rows affected.
# []

# %%
# %%sql
#
# CREATE USER 'pushpa'@'localhost' IDENTIFIED BY '123';
# GRANT ALL PRIVILEGES ON first.* TO 'pushpa'@'localhost';
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# SELECT user, host FROM mysql.user;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 5 rows affected.
# [('mysql.infoschema', 'localhost'),
#  ('mysql.session', 'localhost'),
#  ('mysql.sys', 'localhost'),
#  ('pushpa', 'localhost'),
#  ('root', 'localhost')]

# %%
# %%sql
# SHOW GRANTS FOR 'pushpa'@'localhost';
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 2 rows affected.
# [('GRANT USAGE ON *.* TO `pushpa`@`localhost`',),
#  ('GRANT ALL PRIVILEGES ON `first`.* TO `pushpa`@`localhost`',)]
