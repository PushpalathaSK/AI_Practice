# %%
# %load_ext sql
# %sql mysql+pymysql://root:root@localhost/first

# %%
# %%sql
# show tables;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 2 rows affected.
# [('employee',), ('employees',)]

# %%
# %%sql
# select * from employee;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 0 rows affected.
# []

# %%
# %%sql
#
# insert into employee (id,name,qualification,salary,hire_date)
# values
# (3,'BBB','Engineer',45000,'2025-04-12');
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 1 rows affected.
# []

# %%
# %%sql
# update employee
# set salary=50000
# where id=1;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 1 rows affected.
# []

# %%
# %sql delete from employee where id=2;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 1 rows affected.
# []

# %%
# %%sql
# select * from employee where salary>=45000;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 3 rows affected.
# [(1, 'AAA', 'Engineer', Decimal('50000.00'), datetime.date(2025, 4, 12)),
#  (3, 'BBB', 'Engineer', Decimal('45000.00'), datetime.date(2025, 4, 12)),
#  (3, 'BBB', 'Engineer', Decimal('45000.00'), datetime.date(2025, 4, 12))]

# %%
# %%sql
# select * from employee order by salary;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 3 rows affected.
# [(3, 'BBB', 'Engineer', Decimal('45000.00'), datetime.date(2025, 4, 12)),
#  (3, 'BBB', 'Engineer', Decimal('45000.00'), datetime.date(2025, 4, 12)),
#  (1, 'AAA', 'Engineer', Decimal('50000.00'), datetime.date(2025, 4, 12))]

# %%
# %%sql
# select * from employee order by salary desc;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 3 rows affected.
# [(1, 'AAA', 'Engineer', Decimal('50000.00'), datetime.date(2025, 4, 12)),
#  (3, 'BBB', 'Engineer', Decimal('45000.00'), datetime.date(2025, 4, 12)),
#  (3, 'BBB', 'Engineer', Decimal('45000.00'), datetime.date(2025, 4, 12))]

# %%
# %%sql
#
# select * from employee where name like '%B';
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 2 rows affected.
# [(3, 'BBB', 'Engineer', Decimal('45000.00'), datetime.date(2025, 4, 12)),
#  (3, 'BBB', 'Engineer', Decimal('45000.00'), datetime.date(2025, 4, 12))]

# %%
# %%sql
#
# update employee
# set id=3
# where name='BBB'
# limit 1;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 1 rows affected.
# []

# %%
# %%sql
# select * from employee;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 3 rows affected.
# [(1, 'AAA', 'Engineer', Decimal('50000.00'), datetime.date(2025, 4, 12)),
#  (3, 'BBB', 'Engineer', Decimal('45000.00'), datetime.date(2025, 4, 12)),
#  (2, 'CCC', 'Engineer', Decimal('45000.00'), datetime.date(2025, 4, 12))]
