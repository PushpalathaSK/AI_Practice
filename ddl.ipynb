# %%
# %load_ext sql

# %% [markdown]
# %sql mysql+pymysql://root:root@localhost/first

# %%
# %%sql
# create table employee(
#     id int,
#     name varchar(100),
#     qualification varchar(30),
#     salary decimal(10,2),
#     hire_date date);
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# select * from employee;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 2 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# #alter table employee add dept varchar(100);
# #alter table employee modify dept varchar(30);
# #alter table employee rename column qualification to designation;
# #alter table employee drop column dept;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# #drop table employee;
# #drop database first;
#
# #truncate table employee;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# rename table employee to employees;
# Out:
#  * mysql+pymysql://root:***@localhost/first
# 0 rows affected.
# []
